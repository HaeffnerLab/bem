# %% [markdown]
# # `Documention & Tutorial`
# This BEM package is used for for numerical simulation of the electric field of ion traps in python. Some external packages are wrapped into it:
#
# * fast triangulation (http://www.cs.cmu.edu/~quake/triangle.research.html)
# * fastlap boundary element method (Nabors K S. Efficient three-dimensional capacitance calculation[D]. Massachusetts Institute of Technology, 1993.)
#
# This document, also as a tutorial, explains how to use these packages to compute the electric field and compute its multipole expansion coefficient starting from scratch with a fusion 360 trap model(take `./f3d/htrap_cutout_overhang_9x5mm.f3d` for example). Our document consists of three .ipynb files:
#
# * `I_Mesh_Processing.ipynb`
# * `II_Field_Simulation.ipynb`
# * `III_Multipole_Expansion.ipynb`
#
# We split the document into three files for two reasons:
# 1. The most time consuming part `II_Field_Simulation.ipynb` could be taken out alone and run on a high peformance computer.
# 2. The intermediate result between files can be checked- 'intermediate files' refer to the inital mesh grid (that corresponds to the charge distribution), the simulation values and the simulation coordinates, all of which are saved in the inter_results folder. So if the voltage solution files for the trap don't make sense, it is possible to go back through saved data to see where things have gone wrong.
# Here are the three jupyter notebooks and what:
# 1. I_Mesh_Processing- this notebook generates a mesh of the trap, saved in inter_results as a .pkl file
#
#
# Going through three files in order and running their python code will help you understand our workflow. Generally our workflow divides into three steps, corresponding to the above three .ipynb files. First, in I_Mesh_Processing, we identify different electrodes of the trap model by different colors. Also, we refine the trap model meshes to prepare for the second step. The result is stored in `mesh_result.pkl`.
#
# Secondly, in II_Field_Simulation, we simulate the electric potential with fastlap boundary element method(FMM), the accuracy of this step depends on the mesh size in the first step. The result is stored in `field_result.pkl`.
#
# Thirdly, in III_Multipole_Expansion, we analyze the electric field and electric potential. This notebook generates the multipole coefficients of the fields and potentials for each electrode and uses that information to generate a solution file with the function call `write_csv`. If your solution don't make sense, a good place to start is to insure that the mesh you are using is fine enough (generate several field results for different meshes)- if the potentials and fields are converging to specific values, this suggests there is something wrong with the multipole expansion. If you start with multipole expansion, you do not know if it is a problem with the expansion or with the field.
#
# Before running codes, you must set up the environment according to instructions in `README`
#
# notes
# * Our workflow, as indicated by this document, abandons mayavi(with its embeded package tvtk). But we reserve mayavi in our Bem source code, if you want to use mayavi related functions, you must set up environment with files in`./backup/setup_with_mayavi`, just replace corresponding files in the root folder with them and set up.
#     * why we abandon mayavi: because its python interface(with its dependence vtk and PyQt5) requires complex package dependencies and version controls especially for new python versions. This makes it difficult to maintain this project.
#     * why we still keep mayavi in the source code? Because it is rooted in our source code deeply. We can just avoid invoking related functions instead of deleting them, because they may make sense in the future.

# %% [markdown]
# # `I. Mesh Processing`
# This .pynb file reads a colored model file `./inter_results/htrap_cutout.stl`, and assigns a name for each color(thus for each electrode). The result is stored in `./inter_results/mesh_result.pkl`.
#
# In this file we name different electrodes and refine the meshes. The size of mesh determines the accuracy in next step. You should set the mesh finer and finer until the result converges. Also, you can set the mesh finer and test the convergence.
#
# ## (1) color your electrodes (in fusion 360) and export stl
# First of all, you have a trap model in fusion 360 project, for example, `./f3d/htrap_cutout_overhang_9x5mm.f3d`. Here we use different color to identify different electrodes(STL file stores color for each mesh). In fusion 360, you can assign different appearance for different electrodes. We recommend to use ../../bemCol_lib/bemCol.adsklib for different electrodes. Same color for two electrodes means they are treated as the same electrode. Then we get `./f3d/htrap_cutout_overhang_9x5mm_my_colored.f3d`
#
# Then export to an stl file in fusion360 file>export tab and move the file in `./inter_results`. We export our stl in mm, so we set the mesh unit to mm.

# %% [markdown]
# Furthurmore, it's our convention to use unit mm in our traps. e.g. [Electric field] = V/mm , [harmonic confining potential] = V/mm^2.so we set

# %%
# this is the unit for our Mesh structure
# in the following code, this is the default unit for python variables
#units 
mesh_unit = 1e-3

# %% [markdown]
# Additional notes (from Wenhao):
# * Why use standard color? We define a set of standard color lib `../../../bemCol_lib/bemCol.adsklib` for two reasons: 1. when exporting to .stl file, fusion 360 will compress 0-256 color(RGBA32) into 0-32 color(RGBA16), which means that some similar colors in fusion 360 will become same color after export to .stl file. Our standard color lib avoid this problem. 2.If you use .stl file exported from fusion 360 DIRECTLY, naming the electrodes would be very convinient. If you use other apps such as Inventor or Meshlab to generate .stl file, you can ignore the second reason because color encoding are quite different in different apps

# %% [markdown]
# ## (2) assign a name for each color

# %%
import pickle
import numpy as np
import matplotlib as mpl
import sys
from utils.helper_functions import *
from bem.bemColors_lib.bemColors import bemColors
from bem import Electrodes, Sphere, Mesh, Grid, Configuration, Result, Box
# load stl geometry file
from bem.formats import stl
# stl_path = "roughness/"+"basic_excitation"+".stl"  


#radius is the radius of the sphere from the ions location to generate a finer
#electrode mesh
radius= 500e-3
#'area' is the area of the triangles inside the sphere
area = 1e-4
# file = 'mit_charge'
# file = 'htrap_cutout_overhang_taper_2'
# file_out = 'htrap_cutout_overhang_taper_el3'
# stl_path = 'inter_results/taper_overhang/'+file+'.stl'
# fout_name = 'inter_results/taper_overhang/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


file_out = 'Zhi_trap_130um_el2'
stl_path = 'inter_results/Zhi_trap_130um/FirstV_130um_umScale.stl'
fout_name = 'inter_results/Zhi_trap_130um/'+file_out+'_'+str(radius)+'_'+str(area)+'.pkl'


module_path = os.path.abspath('')


s_nta = stl.read_stl(open(stl_path, "rb"))

# %% [markdown]
# Firstly, we print all the colors appear in the stl file. If a color is of standard colors in `bemCol.adsklib` or named manually by function `bemCol.set_my_color()`, then the color will appear in a straightforward name, such as `bem0`,`bem1` ...... . Otherwise, the color will simply be named as `'_unkCol0'` , `'_unkCol1'`, ...
#
# notes
# * try to comment out the line of `ele_col.set_my_color()` in the following block, name `'_unkCol0'` will appear.

# %%
ele_col = bemColors(np.array(list(set(s_nta[2]))),('fusion360','export_stl'))
ele_col.set_my_color(value = (178,178,178),cl_format = ('fusion360','export_stl','RGBA64'),name = 'self_defined')
ele_col.print_stl_colors()
# Out:
# COLORS in the stl:
# ['bem6']
# ['bem13']
# ['bem19']
# ['bem17']
# ['bem11']
# ['bem15']
# ['bem1']
# ['bem22']
# ['bem12']
# ['bem5']
# ['bem18']
# ['bem16']
# ['bem3']
# ['bem7']
# ['bem23']
# ['bem9']
# ['bem4']
# ['bem2']
# ['bem20']
# ['bem10']
# ['bem14']
# ['bem8']
# ['bem21']
# ['_unkColor0']
# TOTAL COLORS:  24

# %% [markdown]
# Next, you need to assign a name for each color that appeared above. With standard colors defined in `bemCol.adsklib`, the correspondence between color and electrode is clear, which make it easy for this step. You can also comment out some `ele_col.set_color_name()`, run all the codes again and observe the missing part in the printed figure, which corresponds to the electrode you comment out. The second method also serves as a double check. Besides, parameter in `stl.stl_to_mesh()` can be set as `quiet = False` to check whether the program reads planes correctly.

# %%
# assign a name for each color
# taper htrap_cutout 2022
# assign a name for each color

# In od[key] = value, key is the color from the Fusion360 color library we made
# value assigns a specific name to that color in this program. 
# In future version, we may want to consider getting rid of this step for simplification
# then you just assign the color in fusion 360 and be done with it. The only concern there is you
from collections import OrderedDict
od = OrderedDict()
od['bem1']='DC1'
od['bem2']='DC2'
od['bem3']='DC3'
od['bem4']='DC4'
od['bem5']='DC5'
od['bem6']='DC6'
od['bem7']='DC7'
od['bem8']='DC8'
od['bem9']='DC9'
od['bem10']='DC10'
od['bem11']='DC11'
od['bem12']='RF'
od['bem13']='DC12'
od['bem14']='DC13'
od['bem15']='DC14'
od['bem16']='DC15'
od['bem17']='DC16'
od['bem18']='DC17'
od['bem19']='DC18'
od['bem20']='DC19'
od['bem21'] = 'DC20'
od['bem22'] = 'DC21'
od['bem23'] = 'GND'
for key in list(od.keys()):
    ele_col.color_electrode(color=key,name=od[key])

# print colors still with no name. These meshes will be neglected in the code below. 
ele_col.drop_colors()

# read stl into mesh with electrode names
# unnamed meshes will not be imported at all

mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=1,
    rename=ele_col.electrode_colors, quiet=True))
# Out:
# dropping color ['_unkColor0']
# TOTAL COLORS DROPPED:  1
# dropping 20083

# %% [markdown]
# ## (3) remesh
#
# In this step, we generate triangle mesh with constraints. The meshes are 2-dimensional triangles on the surface of electrodes. The region enclosed by constraint shape can have finer mesh. Triangulation is done by `triangle` C library. Folowing variables are all in unit `mesh_unit` now.
#
# Our remesh strategy consists of two steps of triangulation:
# 1. global triangulation without constraint. This step eliminate some long and sharp triangles by combining and dividing, and obtains a coarse grain triangulated model.
# 2. local triangulation with constraint. This step refines each triangles in step 1, the triangle density is defined by `mesh.areas_from_constraints
#
# parameters in the below code block should be tuned specificly for different trap geometries.`

# %%
# here we define a spherical constriant zone:
# xl = 270*1e-3
# yl = -3.5*1e-3
# zl = 72.5*1e-3

#here is the location that will be the reference point for further meshing
#usually, this is the ion's location, specified in appropriate units (usually millimeters)
zl = 2444*1e-3
yl = 130*1e-3
xl = (-138-8-138/2+6)*1e-3

mesh.triangulate(opts="",new = False)

# for z in np.arange(-400e-3,700e-3,100e-3):
print('first triangulation:')
# for z in np.arange(-200e-3, 200e-3, 50e-3):
rad = radius*10
inside=area*300
outside=1
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="a2Q",new = False)

# # what happened to this feature (Box)? is this on bem savio?
# # mesh.areas_from_constraints(Box(start=-0.5, end= 0.5,inside=inside, outside=outside))


# areas_from_constraints specifies sphere with finer mesh inside it.
#  "inside", "outside" set different mesh densities. 
print('second triangulation:')
rad =radius*1
inside=area*2
outside=1e4
mesh.areas_from_constraints(Sphere(center=np.array([xl,yl,zl]),radius=rad, inside=inside, outside=outside))
mesh.triangulate(opts="q5Q",new = False)

# save base mesh to a pickle file
# with open(fout_name,'wb') as f:
#     data = (mesh_unit,
#             xl,
#             yl,
#             zl,
#             mesh,
#             list(od.values()))
#     pickle.dump(data,f)
# Out:
# start triangulate DC20
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC20
# start triangulate DC16
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC16
# start triangulate DC12
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC12
# start triangulate DC10
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC10
# start triangulate DC8
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC8
# start triangulate DC6
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC6
# start triangulate DC4
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC4
# start triangulate DC2
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC2
# start triangulate GND
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate GND
# start triangulate DC13
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC13
# start triangulate DC17
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC17
# start triangulate DC21
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC21
# start triangulate DC19
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC19
# start triangulate DC15
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC15
# start triangulate RF
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate RF
# start triangulate DC1
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC1
# start triangulate DC3
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC3
# start triangulate DC5
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC5
# start triangulate DC7
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC7
# start triangulate DC9
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC9
# start triangulate DC11
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC11
# start triangulate DC14
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC14
# start triangulate DC18
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# final opts zr
# finish triangulate DC18
# first triangulation:
# start triangulate DC20
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC20
# start triangulate DC16
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC16
# start triangulate DC12
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC12
# start triangulate DC10
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC10
# start triangulate DC8
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC8
# start triangulate DC6
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC6
# start triangulate DC4
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC4
# start triangulate DC2
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC2
# start triangulate GND
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate GND
# start triangulate DC13
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC13
# start triangulate DC17
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC17
# start triangulate DC21
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC21
# start triangulate DC19
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC19
# start triangulate DC15
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC15
# start triangulate RF
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate RF
# start triangulate DC1
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC3
# start triangulate DC5
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC5
# start triangulate DC7
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC7
# start triangulate DC9
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC9
# start triangulate DC11
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC11
# start triangulate DC14
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC14
# start triangulate DC18
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# final opts a2Qzra
# finish triangulate DC18
# second triangulation:
# start triangulate DC20
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC20
# start triangulate DC16
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC16
# start triangulate DC12
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC12
# start triangulate DC10
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC10
# start triangulate DC8
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC8
# start triangulate DC6
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC6
# start triangulate DC4
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC4
# start triangulate DC2
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC2
# start triangulate GND
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate GND
# start triangulate DC13
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC13
# start triangulate DC17
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC17
# start triangulate DC21
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC21
# start triangulate DC19
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC19
# start triangulate DC15
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC15
# start triangulate RF
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate RF
# start triangulate DC1
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC1
# start triangulate DC3
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC3
# start triangulate DC5
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC5
# start triangulate DC7
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC7
# start triangulate DC9
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC9
# start triangulate DC11
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC11
# start triangulate DC14
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC14
# start triangulate DC18
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# final opts q5Qzra
# finish triangulate DC18
# Mesh([('DC20',
#        [<bem.triangulation.Triangulation at 0x2151dcf0ee0>,
#         <bem.triangulation.Triangulation at 0x2151fe72040>,
#         <bem.triangulation.Triangulation at 0x2151fe6fb50>,
#         <bem.triangulation.Triangulation at 0x215200d93d0>,
#         <bem.triangulation.Triangulation at 0x215200d9cd0>,
#         <bem.triangulation.Triangulation at 0x215200d9910>,
#         <bem.triangulation.Triangulation at 0x215200ecca0>,
#         <bem.triangulation.Triangulation at 0x215200ecc10>]),
#       ('DC16',
#        [<bem.triangulation.Triangulation at 0x215200ecac0>,
#         <bem.triangulation.Triangulation at 0x2152010c520>,
#         <bem.triangulation.Triangulation at 0x2152010c940>,
#         <bem.triangulation.Triangulation at 0x2152010caf0>,
#         <bem.triangulation.Triangulation at 0x2152010c8b0>,
#         <bem.triangulation.Triangulation at 0x2152010cd00>,
#         <bem.triangulation.Triangulation at 0x2152010c640>,
#         <bem.triangulation.Triangulation at 0x2152010c5e0>,
#         <bem.triangulation.Triangulation at 0x2152010ccd0>]),
#       ('DC12',
#        [<bem.triangulation.Triangulation at 0x2152010c550>,
#         <bem.triangulation.Triangulation at 0x2152010ca60>,
#         <bem.triangulation.Triangulation at 0x2152010c310>,
#         <bem.triangulation.Triangulation at 0x2152010c8e0>,
#         <bem.triangulation.Triangulation at 0x2152010cb50>,
#         <bem.triangulation.Triangulation at 0x2152010cf10>]),
#       ('DC10',
#        [<bem.triangulation.Triangulation at 0x2152010ce20>,
#         <bem.triangulation.Triangulation at 0x2152010c910>,
#         <bem.triangulation.Triangulation at 0x2152010c460>,
#         <bem.triangulation.Triangulation at 0x2152010ca90>,
#         <bem.triangulation.Triangulation at 0x215200c7400>,
#         <bem.triangulation.Triangulation at 0x2151daaa490>,
#         <bem.triangulation.Triangulation at 0x2151fefad60>,
#         <bem.triangulation.Triangulation at 0x2151fe91130>,
#         <bem.triangulation.Triangulation at 0x2151ff0a7c0>,
#         <bem.triangulation.Triangulation at 0x2152002fa00>]),
#       ('DC8',
#        [<bem.triangulation.Triangulation at 0x2152002fdf0>,
#         <bem.triangulation.Triangulation at 0x2152002d610>,
#         <bem.triangulation.Triangulation at 0x2152002d8b0>,
#         <bem.triangulation.Triangulation at 0x21520105790>,
#         <bem.triangulation.Triangulation at 0x21520105850>,
#         <bem.triangulation.Triangulation at 0x21520105970>,
#         <bem.triangulation.Triangulation at 0x21520105a60>]),
#       ('DC6',
#        [<bem.triangulation.Triangulation at 0x215201050d0>,
#         <bem.triangulation.Triangulation at 0x21520105700>,
#         <bem.triangulation.Triangulation at 0x21520105b50>,
#         <bem.triangulation.Triangulation at 0x215201052e0>]),
#       ('DC4',
#        [<bem.triangulation.Triangulation at 0x21520105220>,
#         <bem.triangulation.Triangulation at 0x21520105160>,
#         <bem.triangulation.Triangulation at 0x21520105ca0>,
#         <bem.triangulation.Triangulation at 0x21520105730>]),
#       ('DC2',
#        [<bem.triangulation.Triangulation at 0x21520105610>,
#         <bem.triangulation.Triangulation at 0x21520105520>,
#         <bem.triangulation.Triangulation at 0x21520105460>,
#         <bem.triangulation.Triangulation at 0x21520105340>,
#         <bem.triangulation.Triangulation at 0x21520105e20>,
#         <bem.triangulation.Triangulation at 0x21520105f70>,
#         <bem.triangulation.Triangulation at 0x21520105b80>]),
#       ('GND',
#        [<bem.triangulation.Triangulation at 0x2151ffdf6a0>,
#         <bem.triangulation.Triangulation at 0x2151ffdf790>,
#         <bem.triangulation.Triangulation at 0x215200de460>,
#         <bem.triangulation.Triangulation at 0x215200de8e0>,
#         <bem.triangulation.Triangulation at 0x215200b2850>,
#         <bem.triangulation.Triangulation at 0x2151fd73b20>,
#         <bem.triangulation.Triangulation at 0x2152006a640>,
#         <bem.triangulation.Triangulation at 0x2151ffac040>,
#         <bem.triangulation.Triangulation at 0x2151ffacca0>,
#         <bem.triangulation.Triangulation at 0x215200f3340>,
#         <bem.triangulation.Triangulation at 0x215200f3a00>,
#         <bem.triangulation.Triangulation at 0x215200fd4f0>,
#         <bem.triangulation.Triangulation at 0x215200fd3a0>,
#         <bem.triangulation.Triangulation at 0x215200f7820>,
#         <bem.triangulation.Triangulation at 0x215200f7580>,
#         <bem.triangulation.Triangulation at 0x215200f7d60>,
#         <bem.triangulation.Triangulation at 0x2151fffd220>,
#         <bem.triangulation.Triangulation at 0x2151fffd760>,
#         <bem.triangulation.Triangulation at 0x2151fffd5e0>,
#         <bem.triangulation.Triangulation at 0x2151fffd370>,
#         <bem.triangulation.Triangulation at 0x2151ff29970>,
#         <bem.triangulation.Triangulation at 0x2151ff29a30>,
#         <bem.triangulation.Triangulation at 0x2151ff29880>,
#         <bem.triangulation.Triangulation at 0x215200ba400>,
#         <bem.triangulation.Triangulation at 0x21520103dc0>,
#         <bem.triangulation.Triangulation at 0x215201030d0>,
#         <bem.triangulation.Triangulation at 0x21520103220>,
#         <bem.triangulation.Triangulation at 0x21520103310>,
#         <bem.triangulation.Triangulation at 0x21520103430>,
#         <bem.triangulation.Triangulation at 0x215201035e0>,
#         <bem.triangulation.Triangulation at 0x21520103760>,
#         <bem.triangulation.Triangulation at 0x21520103850>,
#         <bem.triangulation.Triangulation at 0x21520103970>,
#         <bem.triangulation.Triangulation at 0x21520103ac0>,
#         <bem.triangulation.Triangulation at 0x21520103bb0>,
#         <bem.triangulation.Triangulation at 0x21520103ca0>,
#         <bem.triangulation.Triangulation at 0x21520103d90>,
#         <bem.triangulation.Triangulation at 0x21520103eb0>,
#         <bem.triangulation.Triangulation at 0x21520103fa0>,
#         <bem.triangulation.Triangulation at 0x21520103340>,
#         <bem.triangulation.Triangulation at 0x21520103100>,
#         <bem.triangulation.Triangulation at 0x21520103610>,
#         <bem.triangulation.Triangulation at 0x2151fffb7f0>,
#         <bem.triangulation.Triangulation at 0x2151fffbfa0>,
#         <bem.triangulation.Triangulation at 0x2152010ffa0>,
#         <bem.triangulation.Triangulation at 0x2152010f220>,
#         <bem.triangulation.Triangulation at 0x2152010f520>,
#         <bem.triangulation.Triangulation at 0x2152010f430>,
#         <bem.triangulation.Triangulation at 0x2152010faf0>,
#         <bem.triangulation.Triangulation at 0x2152010fd00>,
#         <bem.triangulation.Triangulation at 0x2152010f0d0>,
#         <bem.triangulation.Triangulation at 0x2152010f2e0>,
#         <bem.triangulation.Triangulation at 0x2152010f190>,
#         <bem.triangulation.Triangulation at 0x2152010f460>,
#         <bem.triangulation.Triangulation at 0x2152010f5e0>,
#         <bem.triangulation.Triangulation at 0x2152010f7f0>,
#         <bem.triangulation.Triangulation at 0x2152010f970>,
#         <bem.triangulation.Triangulation at 0x2152010fb20>,
#         <bem.triangulation.Triangulation at 0x2152010fc40>,
#         <bem.triangulation.Triangulation at 0x2152010fe20>,
#         <bem.triangulation.Triangulation at 0x2152010ff70>,
#         <bem.triangulation.Triangulation at 0x2152010f400>,
#         <bem.triangulation.Triangulation at 0x21520025250>,
#         <bem.triangulation.Triangulation at 0x21520025190>,
#         <bem.triangulation.Triangulation at 0x215200251f0>,
#         <bem.triangulation.Triangulation at 0x2151ffef280>,
#         <bem.triangulation.Triangulation at 0x2151dce8df0>,
#         <bem.triangulation.Triangulation at 0x2151ffe6940>,
#         <bem.triangulation.Triangulation at 0x2151ffe65e0>,
#         <bem.triangulation.Triangulation at 0x2151fd6a310>,
#         <bem.triangulation.Triangulation at 0x2151fe6d280>,
#         <bem.triangulation.Triangulation at 0x2151fe6d490>,
#         <bem.triangulation.Triangulation at 0x2151fef22e0>,
#         <bem.triangulation.Triangulation at 0x2151ffdbeb0>,
#         <bem.triangulation.Triangulation at 0x2151ffdb9a0>,
#         <bem.triangulation.Triangulation at 0x2151ffdb400>,
#         <bem.triangulation.Triangulation at 0x2151ffdb8b0>,
#         <bem.triangulation.Triangulation at 0x2151ffdbf10>,
#         <bem.triangulation.Triangulation at 0x215200e0d00>,
#         <bem.triangulation.Triangulation at 0x215200e0a60>,
#         <bem.triangulation.Triangulation at 0x215200e0a30>,
#         <bem.triangulation.Triangulation at 0x2151fe7aa60>,
#         <bem.triangulation.Triangulation at 0x215200710d0>,
#         <bem.triangulation.Triangulation at 0x215200b9580>,
#         <bem.triangulation.Triangulation at 0x215200b9640>,
#         <bem.triangulation.Triangulation at 0x215200e5730>,
#         <bem.triangulation.Triangulation at 0x215200e5eb0>,
#         <bem.triangulation.Triangulation at 0x215200e5550>,
#         <bem.triangulation.Triangulation at 0x2151fe617f0>,
#         <bem.triangulation.Triangulation at 0x2151fe61880>,
#         <bem.triangulation.Triangulation at 0x2152007d430>,
#         <bem.triangulation.Triangulation at 0x2151dae93a0>,
#         <bem.triangulation.Triangulation at 0x2151b9fd310>,
#         <bem.triangulation.Triangulation at 0x215200663d0>,
#         <bem.triangulation.Triangulation at 0x215200660d0>,
#         <bem.triangulation.Triangulation at 0x2151fff12b0>,
#         <bem.triangulation.Triangulation at 0x2151fff1190>,
#         <bem.triangulation.Triangulation at 0x2151fe6a370>,
#         <bem.triangulation.Triangulation at 0x2151fe6a880>,
#         <bem.triangulation.Triangulation at 0x215200dd610>,
#         <bem.triangulation.Triangulation at 0x215200dd0a0>,
#         <bem.triangulation.Triangulation at 0x215200dd4f0>,
#         <bem.triangulation.Triangulation at 0x215200ddf10>,
#         <bem.triangulation.Triangulation at 0x215200dd070>,
#         <bem.triangulation.Triangulation at 0x2151fef5730>,
#         <bem.triangulation.Triangulation at 0x2151fef5430>,
#         <bem.triangulation.Triangulation at 0x2151fef5520>,
#         <bem.triangulation.Triangulation at 0x215200a6fd0>,
#         <bem.triangulation.Triangulation at 0x215200a6be0>,
#         <bem.triangulation.Triangulation at 0x215200fc2e0>,
#         <bem.triangulation.Triangulation at 0x215200fc880>,
#         <bem.triangulation.Triangulation at 0x215200fc250>,
#         <bem.triangulation.Triangulation at 0x215200fc760>,
#         <bem.triangulation.Triangulation at 0x215200fc100>,
#         <bem.triangulation.Triangulation at 0x215200fcb80>,
#         <bem.triangulation.Triangulation at 0x215200fc4f0>,
#         <bem.triangulation.Triangulation at 0x215200e3e50>,
#         <bem.triangulation.Triangulation at 0x215200e3730>,
#         <bem.triangulation.Triangulation at 0x2151feff190>,
#         <bem.triangulation.Triangulation at 0x2151feff9d0>,
#         <bem.triangulation.Triangulation at 0x2151feff700>,
#         <bem.triangulation.Triangulation at 0x215201291c0>,
#         <bem.triangulation.Triangulation at 0x21520129b20>,
#         <bem.triangulation.Triangulation at 0x215201294c0>,
#         <bem.triangulation.Triangulation at 0x21520129be0>,
#         <bem.triangulation.Triangulation at 0x21520129af0>,
#         <bem.triangulation.Triangulation at 0x215200d7070>,
#         <bem.triangulation.Triangulation at 0x215200d77c0>,
#         <bem.triangulation.Triangulation at 0x215200d77f0>,
#         <bem.triangulation.Triangulation at 0x2151fefc0a0>,
#         <bem.triangulation.Triangulation at 0x2151fefca30>,
#         <bem.triangulation.Triangulation at 0x2151ffd9580>,
#         <bem.triangulation.Triangulation at 0x2151ffd9640>,
#         <bem.triangulation.Triangulation at 0x2151ffd9670>,
#         <bem.triangulation.Triangulation at 0x2151ffd9ee0>,
#         <bem.triangulation.Triangulation at 0x2152001eb50>,
#         <bem.triangulation.Triangulation at 0x2152001e9a0>,
#         <bem.triangulation.Triangulation at 0x2152001ef10>,
#         <bem.triangulation.Triangulation at 0x2152001eee0>,
#         <bem.triangulation.Triangulation at 0x2152001eca0>,
#         <bem.triangulation.Triangulation at 0x215201040d0>,
#         <bem.triangulation.Triangulation at 0x21520104100>,
#         <bem.triangulation.Triangulation at 0x215201041c0>,
#         <bem.triangulation.Triangulation at 0x21520104280>,
#         <bem.triangulation.Triangulation at 0x215201043a0>,
#         <bem.triangulation.Triangulation at 0x215201044c0>,
#         <bem.triangulation.Triangulation at 0x215201045b0>,
#         <bem.triangulation.Triangulation at 0x215201046a0>,
#         <bem.triangulation.Triangulation at 0x21520104790>,
#         <bem.triangulation.Triangulation at 0x215201048b0>,
#         <bem.triangulation.Triangulation at 0x215201049a0>]),
#       ('DC13',
#        [<bem.triangulation.Triangulation at 0x21520104a60>,
#         <bem.triangulation.Triangulation at 0x21520104b80>,
#         <bem.triangulation.Triangulation at 0x21520104c40>,
#         <bem.triangulation.Triangulation at 0x21520104d30>,
#         <bem.triangulation.Triangulation at 0x21520104e50>,
#         <bem.triangulation.Triangulation at 0x21520104f40>,
#         <bem.triangulation.Triangulation at 0x21520104340>,
#         <bem.triangulation.Triangulation at 0x21520104f10>,
#         <bem.triangulation.Triangulation at 0x2152000a8e0>,
#         <bem.triangulation.Triangulation at 0x2152000a9d0>]),
#       ('DC17',
#        [<bem.triangulation.Triangulation at 0x2152000a340>,
#         <bem.triangulation.Triangulation at 0x2152000a580>,
#         <bem.triangulation.Triangulation at 0x2152000a940>,
#         <bem.triangulation.Triangulation at 0x2152000aa60>,
#         <bem.triangulation.Triangulation at 0x2151daf5d90>,
#         <bem.triangulation.Triangulation at 0x21520121f40>,
#         <bem.triangulation.Triangulation at 0x21520121220>,
#         <bem.triangulation.Triangulation at 0x215201213d0>]),
#       ('DC21',
#        [<bem.triangulation.Triangulation at 0x215201214f0>,
#         <bem.triangulation.Triangulation at 0x21520121760>,
#         <bem.triangulation.Triangulation at 0x215201217c0>,
#         <bem.triangulation.Triangulation at 0x215201218e0>,
#         <bem.triangulation.Triangulation at 0x21520121a90>,
#         <bem.triangulation.Triangulation at 0x21520121c70>,
#         <bem.triangulation.Triangulation at 0x21520121df0>,
#         <bem.triangulation.Triangulation at 0x21520121eb0>,
#         <bem.triangulation.Triangulation at 0x21520121190>]),
#       ('DC19',
#        [<bem.triangulation.Triangulation at 0x21520109be0>,
#         <bem.triangulation.Triangulation at 0x21520109d00>,
#         <bem.triangulation.Triangulation at 0x21520109e20>,
#         <bem.triangulation.Triangulation at 0x21520109280>,
#         <bem.triangulation.Triangulation at 0x21520109070>,
#         <bem.triangulation.Triangulation at 0x21520109220>]),
#       ('DC15',
#        [<bem.triangulation.Triangulation at 0x21520109310>,
#         <bem.triangulation.Triangulation at 0x21520109490>,
#         <bem.triangulation.Triangulation at 0x215201095e0>,
#         <bem.triangulation.Triangulation at 0x21520109790>,
#         <bem.triangulation.Triangulation at 0x21520109910>,
#         <bem.triangulation.Triangulation at 0x21520109a90>,
#         <bem.triangulation.Triangulation at 0x21520109bb0>]),
#       ('RF',
#        [<bem.triangulation.Triangulation at 0x21520109df0>,
#         <bem.triangulation.Triangulation at 0x21520109a00>,
#         <bem.triangulation.Triangulation at 0x21520109dc0>,
#         <bem.triangulation.Triangulation at 0x21520109d60>,
#         <bem.triangulation.Triangulation at 0x21520120040>,
#         <bem.triangulation.Triangulation at 0x21520120160>,
#         <bem.triangulation.Triangulation at 0x21520120280>,
#         <bem.triangulation.Triangulation at 0x21520120340>,
#         <bem.triangulation.Triangulation at 0x21520120460>,
#         <bem.triangulation.Triangulation at 0x21520120580>]),
#       ('DC1',
#        [<bem.triangulation.Triangulation at 0x21520120640>,
#         <bem.triangulation.Triangulation at 0x21520120730>,
#         <bem.triangulation.Triangulation at 0x21520120880>,
#         <bem.triangulation.Triangulation at 0x215201209a0>,
#         <bem.triangulation.Triangulation at 0x21520120a90>,
#         <bem.triangulation.Triangulation at 0x21520120b80>]),
#       ('DC3',
#        [<bem.triangulation.Triangulation at 0x21520120ca0>,
#         <bem.triangulation.Triangulation at 0x21520120dc0>,
#         <bem.triangulation.Triangulation at 0x21520120fd0>,
#         <bem.triangulation.Triangulation at 0x21520120eb0>]),
#       ('DC5',
#        [<bem.triangulation.Triangulation at 0x21520125460>,
#         <bem.triangulation.Triangulation at 0x21520125400>,
#         <bem.triangulation.Triangulation at 0x21520125280>,
#         <bem.triangulation.Triangulation at 0x215201255e0>]),
#       ('DC7',
#        [<bem.triangulation.Triangulation at 0x21520126190>,
#         <bem.triangulation.Triangulation at 0x215201262b0>,
#         <bem.triangulation.Triangulation at 0x215201264f0>,
#         <bem.triangulation.Triangulation at 0x21520126970>,
#         <bem.triangulation.Triangulation at 0x215201265b0>,
#         <bem.triangulation.Triangulation at 0x215201263a0>,
#         <bem.triangulation.Triangulation at 0x21520126bb0>,
#         <bem.triangulation.Triangulation at 0x21520126ee0>,
#         <bem.triangulation.Triangulation at 0x21520126ac0>,
#         <bem.triangulation.Triangulation at 0x21520126dc0>]),
#       ('DC9',
#        [<bem.triangulation.Triangulation at 0x2151ff2b2e0>,
#         <bem.triangulation.Triangulation at 0x215201070a0>,
#         <bem.triangulation.Triangulation at 0x21520107160>,
#         <bem.triangulation.Triangulation at 0x215201072e0>,
#         <bem.triangulation.Triangulation at 0x21520107490>,
#         <bem.triangulation.Triangulation at 0x21520107610>,
#         <bem.triangulation.Triangulation at 0x21520107850>]),
#       ('DC11',
#        [<bem.triangulation.Triangulation at 0x215201079a0>,
#         <bem.triangulation.Triangulation at 0x21520107b20>,
#         <bem.triangulation.Triangulation at 0x21520107ca0>,
#         <bem.triangulation.Triangulation at 0x21520107e80>]),
#       ('DC14',
#        [<bem.triangulation.Triangulation at 0x21520107b50>,
#         <bem.triangulation.Triangulation at 0x215201071f0>,
#         <bem.triangulation.Triangulation at 0x2152012b1c0>,
#         <bem.triangulation.Triangulation at 0x2152012b5e0>,
#         <bem.triangulation.Triangulation at 0x2152012b820>]),
#       ('DC18',
#        [<bem.triangulation.Triangulation at 0x2152012b9a0>,
#         <bem.triangulation.Triangulation at 0x2152012bd00>,
#         <bem.triangulation.Triangulation at 0x2152012bf40>,
#         <bem.triangulation.Triangulation at 0x2152012b7f0>,
#         <bem.triangulation.Triangulation at 0x2152012ba30>,
#         <bem.triangulation.Triangulation at 0x2152012bdc0>,
#         <bem.triangulation.Triangulation at 0x2151fef7850>,
#         <bem.triangulation.Triangulation at 0x215200f8730>])])

# %%
# save base mesh to a pickle file
with open(fout_name,'wb') as f:
    data = (mesh_unit,
            xl,
            yl,
            zl,
            mesh,
            list(od.values()))
    pickle.dump(data,f)

# %% [markdown]
# ## view mesh
# Uses Pyvista package to generate interactive 3-d plot of the mesh

# %%
# Plot triangle mezshes of the final mesh
mesh.plot()

# %% [markdown]
# Show number of points included in the mesh

# %%
print(len(mesh.points))
# Out:
# 8791
